# %% [markdown]
# ### импортируем библиотеки

# %%
import os
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

import missingno as msno

import scipy.stats
from scipy.stats import spearmanr, kendalltau, chi2_contingency, pointbiserialr

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### обработка файла

# %%
file_path = 'C:\\Users\\AnnaZheleznova\\Documents\\Cource_BigData\\Diplom_github\\fz.zip'
chunksize = 10 ** 6
i = 0
with pd.read_csv(file_path, chunksize=chunksize, on_bad_lines="skip",dtype='unicode', header=None) as reader:
    for df in reader:
        if i < 3:
            i += 1
        break

# %%
df.head(10)
# Out:
#    0                    1                                     2           3   \
# 0   1  1010101008321000006  211010101008301010100100100246820244  7707049388
# 1   2  1010101008321000006  211010101008301010100100100246820244  7707049388
# 2   3  1010101008321000007  211010101008301010100100100236820244  0105076166
# 3   4  1010501691421000144  211010501691401050100101960012640323  6630008994
# 4   6  1010501691421000148  211010501691401050100101940012640323  7743763319
# 5   8  1010501691421000150  211010501691401050100102290015310244  7724490000
# 6   9  1010501691421000151  211010501691401050100102010012660323  7130033105
# 7  10  1010501691421000152  211010501691401050100101930012660323  7105057864
# 8  11  1010501691421000153  211010501691401050100102040013250323  2310170944
# 9  12  1010501691421000154  211010501691401050100102040053250323  2310170944
#
#                                                   4                5   \
# ...

# %%
# выводим все колонки выставив опцию
# pd.set_option('display.max_columns', None)

# %%
# выводим все колонки с помощью display
from IPython.display import display
display(df.head(2))
# Out:
#   0                    1                                     2           3   \
# 0  1  1010101008321000006  211010101008301010100100100246820244  7707049388
# 1  2  1010101008321000006  211010101008301010100100100246820244  7707049388
#
#                                               4                5           6   \
# 0        КРАСНОДАРСКИЙ ФИЛИАЛ ПАО \РОСТЕЛЕКОМ\""  <НЕ ОПРЕДЕЛЕНО>  0101010083
# 1  ПУБЛИЧНОЕ АКЦИОНЕРНОЕ ОБЩЕСТВО \РОСТЕЛЕКОМ\""               78  0101010083
#
#                                 7                           8   \
# 0  МО МВД РОССИИ \КОШЕХАБЛЬСКИЙ\""  Республика Адыгея (Адыгея)
# 1  МО МВД РОССИИ \КОШЕХАБЛЬСКИЙ\""  Республика Адыгея (Адыгея)
#
#                      9                  10               11  \
# 0  18803020840390049244  Контракт исполнен  <НЕ ОПРЕДЕЛЕНО>
# 1  18803020840390049244  Контракт исполнен  <НЕ ОПРЕДЕЛЕНО>
#
#                    12          13          14          15          16  \
# ...
